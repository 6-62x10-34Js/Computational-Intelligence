# %%
import numpy as np
from numpy import linalg as la
import scipy as sp
import matplotlib.pyplot as plt
from IPython import display
import time
import csv

# %% [markdown]
# We apply (i) k-Means and (ii) EM for hard-/ soft classification on the vowels data set. Parts of this notebook will be updated after the deadline of assignment 4.

# %%
# load data
a = np.genfromtxt('a.csv')
e = np.genfromtxt('e.csv')
i = np.genfromtxt('i.csv')
o = np.genfromtxt('o.csv')
y = np.genfromtxt('y.csv')
allvow = np.genfromtxt('allvow.csv')

# %%
# plot data (with and without class-lable)
plt.rcParams['figure.figsize'] = 30, 20
plt.rcParams["font.size"] = "20"
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

ax1.scatter(a[:,0], a[:,1])
ax1.scatter(e[:,0], e[:,1])
ax1.scatter(i[:,0], i[:,1])
ax1.scatter(o[:,0], o[:,1])
ax1.scatter(y[:,0], y[:,1])

ax2.scatter(allvow[:,0], allvow[:,1])

plt.show()

# %% [markdown]
# # (i) k-Means

# %%
# Implement k-Means

def kmeans(data,nr_centers=None, center_means=None):
    
    # Updated after deadline of assignment 4

# %% [markdown]
# ## Perform kmeans

# %%
data = allvow
nr_centers = 5

nr_samples = data.shape[0]
nr_dimensions = data.shape[1]
assert nr_samples > nr_dimensions


center_means = True#None #True
plot_sequential = False 
#plot_sequential = True

kmeans(data,nr_centers=nr_centers)

# %% [markdown]
# # (ii) EM

# %%
from scipy.stats import multivariate_normal
import matplotlib.mlab as mlab

var_initial = 10000
#var_initial = 1000

# Define some GMM helper functions

#----------------------------------------------------------------
def get_posterior(data,mean,cov):
    
    # Updated after deadline of assignment 4
    
#-------------------------------------------------------------
-
def update_parameters(posterior,data,mean,cov,prior):
    
    # Updated after deadline of assignment 4
    
#----------------------------------------------------------------
def init_gmm(nr_components=None,mean=None,cov=None,prior=None):
    
    # Updated after deadline of assignment 4

# %% [markdown]
# ## Perform EM

# %%
data = allvow
nr_components = 5
plot_sequential = False
plot_sequential = True
nr_samples = data.shape[0]
nr_dimensions = data.shape[1]
assert nr_samples > nr_dimensions

#set max_iter and tol
max_iter = 200
tolerance = 0.01

# Init gmm
(nr_components,mean,cov,prior) = init_gmm(nr_components=5)

# Init log-likelihood (for plotting)
log_likelihood = np.zeros((1,max_iter))

# Perform EM

    # Updated after deadline of assignment 4
# Out:
# Converged after 46 iterations
